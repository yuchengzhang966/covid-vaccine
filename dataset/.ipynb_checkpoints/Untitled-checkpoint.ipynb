# %%
import numpy as np
import pandas as pd

# %%
df2=pd.read_csv("covid2.csv")

# %%
df2.head()
# Out:
#    Unnamed: 0  iso_code continent     location        date    population  \
# 0           0       AFG      Asia  Afghanistan  2020-02-24  3.892834e+07
# 1           1  OWID_AFR       NaN       Africa  2020-02-13  1.340598e+09
# 2           2       ALB    Europe      Albania  2020-02-25  2.877800e+06
# 3           3       DZA    Africa      Algeria  2020-02-25  4.385104e+07
# 4           4       AND    Europe      Andorra  2020-03-02  7.726500e+04
#
#    population_density  median_age  aged_65_older  aged_70_older  \
# 0              54.422        18.6          2.581          1.337
# 1                 NaN         NaN            NaN            NaN
# 2             104.871        38.0         13.188          8.643
# 3              17.348        29.1          6.211          3.857
# 4             163.755         NaN            NaN            NaN
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# ...

# %%
for index in df2.index/100:
    print(df2.loc[index]['iso_code'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b1f077143e77> in <module>
#       1 for index in df2.index/100:
# ----> 2     print(df2.loc[index][iso_code])
#
# NameError: name 'iso_code' is not defined
