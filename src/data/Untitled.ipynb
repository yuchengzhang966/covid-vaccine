# %%
import numpy as np
import pandas as pd

# %%
df2=pd.read_csv("covid2.csv")

# %%
df2.head()
df2.index
# Out:
# RangeIndex(start=0, stop=436, step=1)

# %%
for ind in df2.index:
    if (len(df2.loc[ind]['iso_code'])!=3):
        print(df2.loc[ind]['iso_code'])
        df2=df2.drop(index=ind)
# Out:
# OWID_AFR
# OWID_ASI
# OWID_EUR
# OWID_EUN
# OWID_INT
# OWID_KOS
# OWID_NAM
# OWID_CYN
# OWID_OCE
# OWID_SAM
# OWID_WRL
# OWID_AFR
# OWID_ASI
# OWID_EUR
# OWID_EUN
# OWID_INT
# OWID_KOS
# OWID_NAM
# OWID_CYN
# OWID_OCE
# OWID_SAM
# OWID_WRL

# %%
df2.index
# Out:
# Int64Index([  0,   2,   3,   4,   5,   6,   7,   8,   9,  11,
#             ...
#             425, 426, 427, 428, 429, 430, 431, 433, 434, 435],
#            dtype='int64', length=414)

# %%
df2.describe()
# Out:
#        Unnamed: 0    population  population_density  median_age  \
# count  414.000000  4.140000e+02          394.000000  370.000000
# mean   217.594203  3.747101e+07          459.825350   30.268649
# std    125.959694  1.433073e+08         2137.371372    9.170460
# min      0.000000  8.090000e+02            0.137000   15.100000
# 25%    109.250000  1.031042e+06           36.253000   22.000000
# 50%    217.500000  7.132530e+06           85.129000   29.400000
# 75%    326.750000  2.650397e+07          212.865000   38.700000
# max    435.000000  1.439324e+09        20546.766000   48.200000
#
#        aged_65_older  aged_70_older  gdp_per_capita  extreme_poverty  \
# count     366.000000     368.000000      374.000000       246.000000
# mean        8.629120       5.452174    19199.099540        14.073171
# std         6.169397       4.201053    20631.624856        20.314977
# min         1.144000       0.526000      661.240000         0.100000
# ...

# %%
df2.to_csv('covid2.csv')
